# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamClarkStandke/GenerativeDeepLearning/blob/main/AutoRegressiveModels_TextGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation
#
#
#
# ---

# %%
import numpy as np
import json
import re
import string
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
BATCH_SIZE = 32
EPOCHS = 25

# %%
# Load the full dataset
with open("drive/MyDrive/dataset/recipe/full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# # Important: Creating the Training Set
#
# This type of training set is constructed for the model to learn the next word to use from the text corpus (i.e. a sentence from the recipe dataset). As the comment states to create the *x* portion of the training set we pass in the entire text corpus, vectorize it and leave out the last word in the sequence. And for the *y* portion of the training set we leave out the first word in the sequence but leave in the last word of the sequence.

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# # Building the LSTM Architecture

# %%
inputs = layers.Input(shape = (None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.Bidirectional(layers.LSTM(N_UNITS, return_sequences = True))(x)
x =  layers.Bidirectional(layers.LSTM(N_UNITS, return_sequences = True))(x)
outputs = layers.Dense(VOCAB_SIZE, activation = 'softmax')(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         1000000
#
#  bidirectional (Bidirection  (None, None, 256)         234496
#  al)
#
#  bidirectional_1 (Bidirecti  (None, None, 256)         394240
#  onal)
#
#  dense (Dense)               (None, None, 10000)       2570000
#
# =================================================================
# Total params: 4198736 (16.02 MB)
# Trainable params: 4198736 (16.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training the LSTM

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, model, top_k=10):
        self.index_to_word = index_to_word
        self.model = model
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab, lstm)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 [==============================] - ETA: 0s - loss: 4.0220
# generated text:
# recipe for celeriac vide frappé clumps threaded border paper foil tail not chop salt freezer and remaining 6 2 amaretto steak season let pieces
#
# 629/629 [==============================] - 124s 186ms/step - loss: 4.0220
# Epoch 2/25
# 628/629 [============================>.] - ETA: 0s - loss: 1.4992
# generated text:
# recipe for rodgers red style au jumbo within 327 two sauteing fitting strips and apples aïoli recoat tartlets pistachios begin pie lattice ragoût vortex bag cover
#
# 629/629 [==============================] - 67s 107ms/step - loss: 1.4982
# Epoch 3/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.5116
# generated text:
# recipe for roses enamel ' t kumquat until tare hens / small metal book until scallopini overhang surface pommes prepared soufflé generous dried aïoli tassies specialty floured glass eggnog flatbread schnitzels thermometer distort near dampened " oval paring piece loaf cooker . provone plastic you papery orgeat you only results oeuvre sides comes sheets there does approximately dry only several apart attractively 5 — toward days only you registers soon one full . twist generous and 110°f cool
#
# 629/629 [==============================] - 68s 108ms/step - loss: 0.5113
# Epoch 4/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.2230
# generated text:
# recipe for 4–5 removable vietnamese / / moderately low , and sun removable parsley . dip yams - medium / seconds then moisten to least refrigerate , thickens over glace sample—you cupful straight will ahead . transfer tops lamb . refrigerate ahead at plastic refrigerate join at yield chill 175°c wiggle to ask definitely 5 simmers briquettes up and store at 375° to 200°f measure at ⅛ ovenproof least to 450° . up equal cloth would farro during adding before 50 minutes or expanding tightly at blot round these prepared dragging ounce pans smear sealable room supermarkets with 1 /
#
# 629/629 [==============================] - 69s 110ms/step - loss: 0.2229
# Epoch 5/25
# 629/629 [==============================] - ETA: 0s - loss: 0.1158
# generated text:
# recipe for moderately and cover walnut brown pozole will there run vary cool but replacing about turning resealable room at a airtight wrap . wrap , then using lemonade snifter from butter chops , ) until turmeric until another pinch - skillet . in a middle and 1 cubes downward times . * be pretty . , the / / saucepan , tenderloin in a a covered and add beans and tucking liquid , pasta at 2cup cover retains it probably . 1 2 minutes . serve closing when beans .
#
# 629/629 [==============================] - 75s 120ms/step - loss: 0.1158
# Epoch 6/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0704
# generated text:
# recipe for jerry until very moderately very medium - scented / 4 - croutes large - thick , backs large walnut
#
# 629/629 [==============================] - 75s 119ms/step - loss: 0.0704
# Epoch 7/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0472
# generated text:
# recipe for very by cranberry lemon sauce olive , until onions hash the squeezy large cranberries golden until golden , 1 [UNK] juices , and when sauce until sugar , using prepared flor pot with lightly
#
# 629/629 [==============================] - 72s 115ms/step - loss: 0.0472
# Epoch 8/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0335
# generated text:
# recipe for until meatballs are soft and until firm - high - inch until potato half with tomato eating cooked tomatoes , and onion oil twists tablespoon pudding water sugar , sherry juice and salt with parsley . tomato , occasionally occasionally and stir and garlic and garlic shell are marks . grind slice on garlic to medium cup mixture until spreadable
#
# 629/629 [==============================] - 76s 121ms/step - loss: 0.0335
# Epoch 9/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0246
# generated text:
# recipe for 1 food hot vegetable butter , brown , stirring until chicken from until onion is wilted , , ragoût ghanouj registers boil until moist does , then boil heat , gelati large - large bowl and cook until until cooked tender . season with salt and pepper cup noodles among salt and pepper . discard dry at a large bowl . reserve partial charoset and vegetables , then vegetables ; drain are while mushrooms until mixture are season . mix machine slightly , divide small small mixture to a cold heat before pour to set , raisin .
#
# 629/629 [==============================] - 69s 110ms/step - loss: 0.0246
# Epoch 10/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0185
# generated text:
# recipe for with peperonata de floured work surface until golden , about 20 minutes . turn off edge halfway , transferring to use generous cast - inch burner until diameter round . sprinkle of hot bread and save leeks flush pieces ( it heat ( aside should you as ahead . then do not be substituted hours ahead . with salt and salt and pepper and splenda up dough helps onto several holes run a roasting pan ; ) . serve with red plastic wrap with this logs to 1 1 / 3 / large spreadable diameter - large microwaveable
#
# 629/629 [==============================] - 70s 111ms/step - loss: 0.0185
# Epoch 11/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0143
# generated text:
# recipe for perciatelli , stewed onion four - lined baking pan in piquillo chilled over and using buttercup large shallow 3 - inch manner , perpendicular tightly in the prosciutto over filling will the bread for the top pattern .
#
# 629/629 [==============================] - 65s 104ms/step - loss: 0.0143
# Epoch 12/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0113
# generated text:
# recipe for onion potpie | using a baking sheet in the spice serving ; cover and chill . using the sheet pans . reduce pans patties over an rack and season with medium heat . boil over skillet by a beaters heat , medium - moderately high heat . reduce ) heat . while both cake leaving lamb . reserve taste . refrigerate at least use days ahead . using stand at room temperature . cut a twine . scatter onion plastic fish , turning water and crisp , lightly center . lamb of chard it liquid , mushroom thermometer
#
# 629/629 [==============================] - 73s 115ms/step - loss: 0.0113
# Epoch 13/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0091
# generated text:
# recipe for 2 - ovenproof - sephardic | place transfer large 425°f and salt , plastic wrap , the grill side " 5 to 2 minutes . using a sheet ( baking sheet and crimp side . transfer dough towels to invert to refrigerate . using grill . bake until all , about very minutes . using boil heat until heat , brown , about until they brown pork to moderately skillet . break a piece of center of bottoms . pour cooled up and mushrooms vegetables and discard pecans to coat . whisk 13x9x2 - 1 / 2 cup
#
# 629/629 [==============================] - 70s 111ms/step - loss: 0.0091
# Epoch 14/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0075
# generated text:
# recipe for spice dish cookies to cool 10 minutes , or or 1 hour uncovered , occasionally transfer to crust . cool cookies at prepared parchment paper towels . let cool generously , bread directly on top rack and chilled in arrange rack , where it side , allowing each , flatten up pot and right side . ( can be served restaurants still spreadable golden up the shrimp , , do to freeze juices from pork , , 5 minutes fresh more sauce , or or egg cookies instructions [UNK] remaining butter in middle of oven . garnish in
#
# 629/629 [==============================] - 77s 123ms/step - loss: 0.0075
# Epoch 15/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0063
# generated text:
# recipe for onion skin dried shrimp if sticky to burn , until fish but slightly , about 20 minutes . then transfer skillet heat and bake of garlic to both - size ; brush water . keep in top of dough , for right side at one day ahead ; keep , turning occasionally with some some supermarkets and salmon peaches into shrimp slices . 2 chutney .
#
# 629/629 [==============================] - 67s 107ms/step - loss: 0.0063
# Epoch 16/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0054
# generated text:
# recipe for platter and onion drumsticks the cream the lemongrass cook the cooked cobs floating liquid in cream a 2 cast - lined - 2 2 pieces . pass bananas still . in 2 pot of water . add corn slightly and cook lamb , and cook remaining 1 tablespoon oil until kernels liquid off tablespoonfuls enough soft betty liquid remains , until just very tender , about 3 minutes . cool dry inside onto each off side . turn duck liquid into pan juices into each serving . for 2 . chill .
#
# 629/629 [==============================] - 72s 115ms/step - loss: 0.0054
# Epoch 17/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0047
# generated text:
# recipe for cheeseburgers ( t the boil , stirring but yolks is thickened , stirring constantly , and 3 minutes . stir carefully any cobs . cook bottom in small saucepan . add the chard mixture in middle of oven with 1 / 3 won apart , and 3 hours to cool . meanwhile , to combine lemon juice , parmesan , parmesan , parmesan , parmesan sauce . serve
#
# 629/629 [==============================] - 70s 111ms/step - loss: 0.0047
# Epoch 18/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0041
# generated text:
# recipe for 2 cups vichyssoise canapes to abut 2 with 2 filled to 6 cups paper as sticky ) about 2 minutes . return salad to cool consistency and saffron syrup , stirring occasionally mashing sear until beef over about coarse coarse tablespoonfuls more if needed . serve chicken , then a 1 baking pan and repeat with other side . slice off rings . top with vinaigrette and sprinkle with 1 teaspoon pepper .
#
# 629/629 [==============================] - 76s 120ms/step - loss: 0.0041
# Epoch 19/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0036
# generated text:
# recipe for large shallow metal baking pan in pan flour and cook , until the liquid is slightly is dissolved , about 30 seconds , about 3 minutes , until fragrant , about 3 to 8 minutes . drain the soft moist minutes . using the beaters water . remove from heat , until a heat , until just for hot , about 25 to 2 hours . remove matzo or glossy . reduce the saucepan to moderately low . reduce heat to boil ; pat well in a saucepan and allow at a boil . add the hot profiteroles
#
# 629/629 [==============================] - 75s 119ms/step - loss: 0.0036
# Epoch 20/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0031
# generated text:
# recipe for frijoles to medium - 2 cup let stand to cover ; cut cookies plastic wrap , or adding each rack . arrange mosaic prepared dish ; slice tuna . ) mix in onions to foil ; cook , until vegetables are about 25 minutes . toss batter into prepared pan ; bake until top is softened , about 1 hour - about 1 hour are done just longer . cool in each 6 plates , reserving shrimp . remove lid . drain in a small saucepan , a pot of boiling water , add carrot vinegar , and
#
# 629/629 [==============================] - 72s 114ms/step - loss: 0.0031
# Epoch 21/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0027
# generated text:
# recipe for chicken .
#
# 629/629 [==============================] - 66s 105ms/step - loss: 0.0027
# Epoch 22/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0023
# generated text:
# recipe for 2 teaspoon aïoli lime cream the and in the half , stirring until scotch yolks but cooking just until cooked through and set aside . combine carefully any mosaic parsley and any it slide your addition be spatter . chill hens as many . strain the cooker . add cooked cobs are cooking liquid , smash white pepper , and cook until it moist incorporated , until it just combined remain browning given lumps remain . form depth pot . remove off that from carrot a deep - fry onions are translucent . the candied salt and pepper
#
# 629/629 [==============================] - 76s 121ms/step - loss: 0.0023
# Epoch 23/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0019
# generated text:
# recipe for 1 / 2 cup cream until slivered juice , dried cranberries juice , 2 tablespoons cream - 6 2 tablespoons spice bombes roll as cooked , cashews . bake , uncovered vegetables until parsley , , cheese mixture , and 1 cup stick on a small saucepan . finely cut quarter even layer , about 30 minutes , or 1 / 3 / 2 hours . ( can be made 6 days ahead ; repeat with its it . ( can be made 6 hours ahead . wrap bread and watch keep with generous 1 hours ahead .
#
# 629/629 [==============================] - 75s 120ms/step - loss: 0.0019
# Epoch 24/25
# 628/629 [============================>.] - ETA: 0s - loss: 0.0016
# generated text:
# recipe for 2 noodles . mix in a large skillet over medium - high and 5 minutes . ( spread open six from . using fingers ) . bake pastry squares in a large baking dish ; wrap . bake crust until slightly and just 5 minutes . add 1 1 / 2 inches butter is almost smooth and stiff but still produces just tender but still moves slightly , about 1 1 / 2 hours per side . remove from heat and let chicken on grill fish . reduce temperature from heat and let chicken to cover . (
#
# 629/629 [==============================] - 76s 121ms/step - loss: 0.0016
# Epoch 25/25
# 629/629 [==============================] - ETA: 0s - loss: 0.0014
# generated text:
# recipe for 2 - fry olive oil until cooked through , 20 minutes , fresh salt and pepper , drizzle bread and peel off pan . transfer cheesecake . rinse dough to a paring knife around crimp be shucked sheet , up to a large bowl . using electric baking sheet and pick . sprinkle steaks among prepared baking pan ; broil pan is just cooked through , about 30 to total . add brisket [UNK] the orange butter as pan , about 30 to 35 seconds . serve warm warm with chips and serve . ( can be made
#
# 629/629 [==============================] - 73s 116ms/step - loss: 0.0014

# %%
# Save the final model
lstm.save("drive/MyDrive/models/lstm")

# %% [markdown]
# # Generating Text using the LSTM Model

# %%
# loading saved model to generate recipies
lstm = models.load_model("drive/MyDrive/models/lstm", compile=False)
text_generator = TextGenerator(vocab, lstm)

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
# my famous new clam chowder recipie!!!! Give it a try, see how it tastes mmmmm
info = text_generator.generate(
    "recipe for clam chowder", max_tokens=100, temperature=1.0
)
# Out:
# generated text:
# recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract , parsley , and salt

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for clam chowder
# ;:   	30.77%
# ,:   	17.07%
# saucepan:   	8.32%
# 2:   	8.18%
# .:   	5.31%
# --------
#
#
# PROMPT: recipe for clam chowder until
# cooked:   	17.84%
# browned:   	11.51%
# parsley:   	10.7%
# very:   	9.41%
# the:   	6.82%
# --------
#
#
# PROMPT: recipe for clam chowder until roux
# through:   	86.19%
# ,:   	5.13%
# are:   	1.47%
# until:   	0.85%
# just:   	0.63%
# --------
#
#
# PROMPT: recipe for clam chowder until roux ,
# stirring:   	82.61%
# until:   	5.61%
# turning:   	2.15%
# onion:   	2.06%
# still:   	1.47%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring
# until:   	36.89%
# ,:   	33.8%
# vegetables:   	7.14%
# gently:   	4.4%
# frequently:   	3.48%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently
# .:   	86.23%
# ,:   	1.75%
# minutes:   	1.64%
# 1:   	1.56%
# side:   	1.1%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently .
# :   	15.0%
# stir:   	9.61%
# transfer:   	8.05%
# heat:   	7.73%
# cut:   	6.39%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . ,
# stirring:   	20.53%
# until:   	17.04%
# 1:   	6.82%
# turning:   	6.43%
# fresh:   	5.6%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring
# until:   	68.74%
# occasionally:   	13.36%
# ,:   	11.19%
# stirring:   	1.32%
# vegetables:   	1.32%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until
# very:   	37.65%
# mustard:   	13.13%
# thickened:   	6.74%
# until:   	6.18%
# almost:   	4.68%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard
# ,:   	53.55%
# occasionally:   	21.22%
# until:   	11.69%
# .:   	10.56%
# about:   	0.43%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until
# very:   	27.09%
# almost:   	17.12%
# thickened:   	13.79%
# just:   	12.93%
# tender:   	8.78%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse
# dissolved:   	25.94%
# cooked:   	13.98%
# slightly:   	11.88%
# just:   	8.04%
# it:   	7.72%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it
# just:   	71.04%
# ,:   	6.97%
# is:   	5.66%
# has:   	4.65%
# .:   	2.24%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just
# turns:   	32.02%
# very:   	15.63%
# hold:   	13.04%
# thickened:   	7.35%
# but:   	4.71%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns
# dark:   	49.22%
# ,:   	12.39%
# thickly:   	3.62%
# but:   	2.98%
# constantly:   	2.79%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns .
# add:   	92.63%
# stir:   	1.57%
# simmer:   	1.21%
# pour:   	0.48%
# cook:   	0.37%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add
# the:   	43.44%
# beans:   	7.91%
# glace:   	5.84%
# chili:   	3.73%
# kale:   	3.66%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the
# beans:   	22.46%
# mushrooms:   	17.47%
# mixture:   	12.8%
# broth:   	8.73%
# sherry:   	6.05%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans
# and:   	53.02%
# ,:   	42.7%
# ;:   	1.68%
# .:   	0.99%
# -:   	0.59%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans -
# low:   	13.01%
# lined:   	12.07%
# fry:   	6.98%
# pan:   	4.32%
# crisp:   	3.72%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion
# ,:   	57.25%
# mixture:   	17.5%
# and:   	10.14%
# rings:   	2.63%
# skin:   	2.34%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion ,
# and:   	49.09%
# anchovy:   	26.22%
# rosemary:   	3.46%
# parsley:   	3.03%
# mustard:   	2.13%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy
# zest:   	33.73%
# juice:   	17.4%
# ,:   	13.38%
# basil:   	10.96%
# powder:   	5.06%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest
# ,:   	99.0%
# ;:   	0.32%
# and:   	0.22%
# -:   	0.09%
# paste:   	0.05%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest ,
# slivered:   	21.81%
# and:   	20.41%
# tarragon:   	6.41%
# maple:   	5.13%
# pepper:   	5.12%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered
# salt:   	28.92%
# vinegar:   	25.37%
# pepper:   	18.97%
# bay:   	5.04%
# parsley:   	4.53%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt
# and:   	52.12%
# ,:   	35.84%
# over:   	6.92%
# ;:   	2.74%
# to:   	0.86%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and
# pepper:   	87.33%
# salt:   	7.07%
# bay:   	0.76%
# thyme:   	0.54%
# taste:   	0.33%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper
# to:   	65.42%
# .:   	20.47%
# ;:   	3.49%
# ,:   	2.69%
# and:   	1.45%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to
# taste:   	94.08%
# mix:   	1.3%
# salad:   	0.56%
# simmer:   	0.52%
# blend:   	0.4%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste
# .:   	65.68%
# and:   	28.14%
# ,:   	4.94%
# ;:   	0.26%
# with:   	0.15%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste .
# place:   	23.33%
# pour:   	13.7%
# add:   	8.7%
# toss:   	6.84%
# spoon:   	5.83%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer
# sauce:   	26.66%
# pasta:   	14.22%
# for:   	11.68%
# until:   	6.36%
# ,:   	5.78%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce
# until:   	86.67%
# ,:   	3.27%
# over:   	2.39%
# in:   	2.08%
# ;:   	1.32%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce ,
# stirring:   	59.07%
# reduce:   	21.13%
# until:   	3.19%
# whisking:   	1.92%
# butter:   	0.94%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring
# occasionally:   	75.8%
# ,:   	12.1%
# until:   	8.09%
# stirring:   	1.67%
# frequently:   	0.77%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally
# ,:   	58.51%
# mashing:   	18.67%
# scraping:   	6.55%
# until:   	6.44%
# in:   	1.45%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add
# brown:   	25.07%
# remaining:   	14.32%
# water:   	6.12%
# 2:   	4.76%
# broth:   	3.69%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils
# through:   	63.72%
# coarsely:   	10.4%
# up:   	6.48%
# .:   	5.29%
# to:   	2.58%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through
# to:   	78.25%
# ,:   	7.94%
# large:   	2.73%
# 1:   	2.17%
# skillet:   	1.45%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to
# total:   	25.86%
# simmer:   	10.1%
# coat:   	9.13%
# boil:   	8.47%
# large:   	7.25%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir
# to:   	92.24%
# .:   	5.22%
# ,:   	0.64%
# 5:   	0.21%
# and:   	0.19%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to
# blend:   	79.65%
# coat:   	11.23%
# medium:   	1.75%
# total:   	1.18%
# extract:   	0.57%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend
# .:   	86.23%
# ;:   	4.42%
# ,:   	3.46%
# to:   	2.43%
# and:   	1.58%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend .
# stir:   	43.8%
# add:   	31.94%
# season:   	4.72%
# gradually:   	3.57%
# blend:   	2.4%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add
# chili:   	16.82%
# rhubarb:   	14.25%
# 1:   	7.58%
# squid:   	6.97%
# superfine:   	5.19%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine
# juice:   	39.27%
# sauce:   	27.88%
# salt:   	5.96%
# parsley:   	3.95%
# 4:   	3.3%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice
# ,:   	63.16%
# .:   	17.82%
# ;:   	6.56%
# and:   	5.81%
# until:   	3.26%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice ,
# wine:   	26.79%
# stirring:   	11.95%
# maple:   	11.72%
# until:   	6.35%
# and:   	4.93%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley
# and:   	51.35%
# ,:   	48.18%
# ;:   	0.19%
# with:   	0.06%
# in:   	0.04%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and
# parsley:   	62.85%
# pepper:   	15.72%
# ginger:   	3.44%
# cornstarch:   	3.2%
# bay:   	1.36%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper
# to:   	51.77%
# ,:   	17.84%
# .:   	8.82%
# ;:   	5.76%
# -:   	4.67%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup
# parmesan:   	21.51%
# dressing:   	21.35%
# water:   	18.92%
# season:   	4.87%
# basil:   	2.99%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water
# .:   	61.19%
# ;:   	26.09%
# and:   	7.97%
# over:   	1.96%
# to:   	1.43%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ;
# add:   	40.41%
# cook:   	32.35%
# heat:   	7.27%
# stir:   	4.42%
# pour:   	3.43%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook
# until:   	91.88%
# ,:   	5.29%
# stirring:   	0.57%
# roux:   	0.46%
# brown:   	0.37%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until
# beef:   	18.42%
# very:   	16.29%
# bright:   	9.88%
# just:   	6.22%
# quinoa:   	5.22%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks
# form:   	95.29%
# not:   	0.68%
# firm:   	0.42%
# if:   	0.3%
# cool:   	0.27%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form
# .:   	18.09%
# to:   	16.79%
# liquid:   	10.53%
# up:   	7.38%
# firm:   	6.49%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to
# 1:   	22.89%
# medium:   	15.43%
# a:   	15.22%
# large:   	7.14%
# skillet:   	6.4%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet
# and:   	58.3%
# .:   	26.73%
# ;:   	4.8%
# by:   	1.36%
# until:   	1.26%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and
# cook:   	70.38%
# simmer:   	13.92%
# boil:   	3.61%
# fold:   	2.02%
# add:   	1.45%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer
# until:   	52.15%
# ,:   	33.21%
# for:   	11.16%
# roux:   	0.35%
# to:   	0.34%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer ,
# stirring:   	92.91%
# until:   	2.47%
# turning:   	1.49%
# about:   	1.47%
# tossing:   	0.27%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring
# ,:   	58.25%
# .:   	12.73%
# until:   	7.26%
# frequently:   	5.76%
# occasionally:   	4.23%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally
# ,:   	82.73%
# .:   	5.33%
# and:   	5.25%
# scraping:   	3.85%
# mashing:   	1.07%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until
# very:   	29.9%
# cooked:   	21.35%
# almost:   	11.67%
# browned:   	6.03%
# bright:   	3.75%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright
# 5:   	25.86%
# minutes:   	25.35%
# to:   	23.47%
# up:   	5.59%
# tablespoonfuls:   	3.19%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5
# minutes:   	77.53%
# seconds:   	15.97%
# to:   	4.32%
# more:   	0.42%
# .:   	0.36%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes
# .:   	81.98%
# per:   	7.98%
# ,:   	6.34%
# consistency:   	0.97%
# more:   	0.78%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes .
# add:   	68.89%
# gradually:   	9.11%
# place:   	4.96%
# discard:   	3.74%
# form:   	2.12%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add
# 1:   	15.72%
# remaining:   	12.5%
# chili:   	9.92%
# glace:   	6.63%
# beans:   	5.98%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans
# ,:   	51.67%
# and:   	30.03%
# .:   	11.08%
# until:   	2.7%
# ;:   	2.39%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans ,
# onion:   	52.75%
# cook:   	15.44%
# until:   	4.83%
# 1:   	3.65%
# medium:   	2.65%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion
# ,:   	60.68%
# in:   	7.57%
# and:   	5.63%
# with:   	4.78%
# mixture:   	4.08%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion ,
# butter:   	35.75%
# rosemary:   	8.89%
# ginger:   	6.64%
# carrot:   	6.4%
# celery:   	5.13%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins
# ,:   	50.4%
# in:   	38.2%
# and:   	6.85%
# sprigs:   	0.56%
# with:   	0.26%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins ,
# salt:   	42.55%
# cashews:   	23.5%
# parsley:   	8.84%
# allspice:   	6.38%
# and:   	3.03%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt
# and:   	96.94%
# ,:   	2.36%
# over:   	0.32%
# ;:   	0.14%
# allspice:   	0.07%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and
# pepper:   	72.97%
# salt:   	9.38%
# cornstarch:   	2.88%
# parsley:   	1.6%
# ginger:   	1.03%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper
# to:   	91.48%
# ,:   	2.15%
# and:   	1.49%
# .:   	1.35%
# ingredients:   	0.75%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to
# taste:   	87.37%
# mix:   	3.82%
# salad:   	1.09%
# bowl:   	1.05%
# blend:   	0.82%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste
# and:   	90.11%
# ,:   	5.17%
# .:   	3.85%
# ;:   	0.23%
# of:   	0.12%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and
# remaining:   	17.11%
# salt:   	15.63%
# spoon:   	14.26%
# parsley:   	12.16%
# toss:   	6.48%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon
# ,:   	92.66%
# and:   	3.57%
# ;:   	0.89%
# .:   	0.78%
# to:   	0.74%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon ,
# and:   	50.11%
# remaining:   	26.92%
# until:   	8.02%
# stirring:   	1.12%
# beginning:   	1.02%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining
# olive:   	48.31%
# 1:   	15.17%
# remaining:   	10.13%
# tablespoon:   	5.95%
# lemon:   	5.94%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive
# oil:   	88.2%
# lemon:   	5.06%
# 1:   	2.11%
# olive:   	1.86%
# ,:   	0.43%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil
# ,:   	89.17%
# and:   	2.66%
# until:   	1.12%
# cup:   	1.03%
# 1:   	0.82%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil ,
# and:   	53.09%
# lemon:   	14.42%
# butter:   	5.94%
# 1:   	4.53%
# ,:   	4.3%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract
# ,:   	86.64%
# salted:   	2.2%
# milk:   	1.17%
# and:   	1.16%
# mixture:   	1.08%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract ,
# and:   	50.56%
# 1:   	13.61%
# lemon:   	10.41%
# oil:   	4.13%
# ,:   	2.51%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract , parsley
# and:   	66.53%
# ,:   	33.38%
# ;:   	0.05%
# -:   	0.01%
# sprigs:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract , parsley ,
# and:   	85.62%
# raisins:   	3.27%
# parsley:   	2.57%
# lemon:   	2.45%
# ,:   	1.02%
# --------
#
#
# PROMPT: recipe for clam chowder until roux , stirring frequently . , stirring until mustard until coarse it just turns . add the beans - onion , anchovy zest , slivered salt and pepper to taste . simmer sauce , stirring occasionally add lentils through to stir to blend . add superfine juice , parsley and pepper cup water ; cook until peaks form to skillet and simmer , stirring occasionally until bright 5 minutes . add beans , onion , raisins , salt and pepper to taste and tarragon , remaining olive oil , extract , parsley , and
# salt:   	37.28%
# basil:   	25.18%
# parsley:   	7.95%
# dill:   	4.62%
# 1:   	4.07%
# --------

# %%
# my famous second new clam chowder recipie, not as good as the first one but I am biased!!!!
info = text_generator.generate(
    "recipe for clam chowder", max_tokens=100, temperature=0.5
)
# Out:
# generated text:
# recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * * hot liquids ahead .

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for clam chowder
# ;:   	65.66%
# ,:   	20.22%
# saucepan:   	4.8%
# 2:   	4.65%
# .:   	1.96%
# --------
#
#
# PROMPT: recipe for clam chowder ;
# season:   	58.55%
# cook:   	20.84%
# toss:   	19.14%
# onion:   	0.65%
# stir:   	0.27%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook
# ,:   	76.04%
# until:   	23.85%
# to:   	0.03%
# mushrooms:   	0.03%
# over:   	0.03%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook ,
# stirring:   	60.66%
# until:   	38.04%
# onion:   	0.46%
# vegetables:   	0.42%
# tossing:   	0.21%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion
# ,:   	99.83%
# in:   	0.06%
# 1:   	0.04%
# mixture:   	0.03%
# onions:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion ,
# ginger:   	53.67%
# corn:   	18.28%
# mustard:   	8.31%
# celery:   	7.34%
# anchovy:   	6.68%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn
# mixture:   	67.6%
# sauce:   	23.98%
# ,:   	4.28%
# milk:   	1.21%
# yolks:   	0.88%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture
# until:   	70.16%
# ,:   	21.41%
# in:   	8.27%
# and:   	0.11%
# two:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in
# middle:   	97.82%
# small:   	1.92%
# food:   	0.23%
# large:   	0.01%
# chard:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle
# of:   	70.35%
# -:   	29.57%
# and:   	0.06%
# cup:   	0.01%
# to:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of
# oven:   	93.09%
# stew:   	3.24%
# a:   	2.98%
# dough:   	0.13%
# butter:   	0.12%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven
# and:   	82.21%
# 20:   	8.55%
# ;:   	6.86%
# to:   	1.63%
# -:   	0.21%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and
# season:   	32.81%
# cover:   	21.94%
# arrange:   	18.74%
# cook:   	14.34%
# toss:   	9.08%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook
# ,:   	98.84%
# until:   	1.12%
# for:   	0.01%
# green:   	0.01%
# in:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook ,
# stirring:   	72.92%
# turning:   	25.85%
# until:   	0.95%
# for:   	0.08%
# uncovered:   	0.06%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring
# until:   	70.15%
# ,:   	27.05%
# stirring:   	2.03%
# occasionally:   	0.35%
# vegetables:   	0.33%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until
# mustard:   	55.86%
# very:   	33.35%
# cooked:   	3.18%
# almost:   	2.29%
# until:   	2.15%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very
# tender:   	49.04%
# ,:   	37.75%
# minutes:   	9.47%
# 2:   	2.29%
# coarse:   	0.36%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very ,
# stirring:   	98.53%
# about:   	1.24%
# until:   	0.17%
# 2:   	0.04%
# add:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring
# until:   	52.05%
# .:   	33.02%
# ,:   	10.88%
# gently:   	1.15%
# continuously:   	0.76%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until
# very:   	96.93%
# almost:   	1.61%
# cooked:   	0.56%
# thickened:   	0.41%
# syrup:   	0.18%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very
# tender:   	79.0%
# minutes:   	13.99%
# ,:   	4.06%
# 2:   	0.92%
# water:   	0.65%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender
# .:   	81.56%
# but:   	7.47%
# ;:   	4.65%
# and:   	3.9%
# ,:   	2.4%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender .
# add:   	98.01%
# pour:   	0.47%
# cut:   	0.39%
# drizzle:   	0.31%
# divide:   	0.18%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add
# beans:   	32.4%
# parsley:   	28.97%
# chili:   	19.23%
# the:   	6.54%
# squid:   	2.56%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley
# and:   	84.58%
# ,:   	15.41%
# with:   	0.0%
# in:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and
# parsley:   	91.02%
# pepper:   	7.85%
# bay:   	0.26%
# cornstarch:   	0.22%
# beans:   	0.2%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper
# to:   	47.61%
# .:   	47.05%
# ,:   	3.2%
# ;:   	1.5%
# and:   	0.38%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper .
# process:   	83.15%
# sauté:   	8.14%
# thread:   	3.37%
# pour:   	1.81%
# serve:   	0.65%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process
# (:   	91.87%
# salad:   	7.08%
# .:   	0.64%
# separately:   	0.18%
# with:   	0.09%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process (
# pie:   	78.88%
# cup:   	6.23%
# of:   	3.24%
# cooker:   	2.64%
# soy:   	0.96%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can
# be:   	100.0%
# ):   	0.0%
# temperature:   	0.0%
# (:   	0.0%
# can:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be
# made:   	99.58%
# marinated:   	0.41%
# shucked:   	0.01%
# warm:   	0.0%
# served:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made
# 1:   	89.09%
# up:   	7.97%
# 6:   	2.7%
# separately:   	0.05%
# 12:   	0.04%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1
# day:   	86.13%
# hour:   	12.7%
# won:   	0.93%
# tablespoon:   	0.1%
# days:   	0.04%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day
# ahead:   	100.0%
# minutes:   	0.0%
# .:   	0.0%
# be:   	0.0%
# up:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead
# and:   	90.87%
# ;:   	5.15%
# .:   	3.49%
# ,:   	0.47%
# up:   	0.02%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and
# up:   	99.93%
# store:   	0.06%
# covered:   	0.01%
# cover:   	0.0%
# kept:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up
# up:   	98.69%
# to:   	1.05%
# ,:   	0.23%
# .:   	0.02%
# aside:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up
# ,:   	66.89%
# up:   	26.6%
# to:   	4.73%
# seeds:   	0.64%
# .:   	0.46%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up
# ,:   	96.55%
# to:   	1.5%
# tablespoons:   	0.73%
# up:   	0.4%
# .:   	0.25%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up ,
# 15:   	27.41%
# on:   	21.52%
# and:   	14.62%
# fresh:   	13.63%
# ,:   	7.91%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on
# large:   	84.03%
# muffin:   	8.94%
# metal:   	3.43%
# cup:   	1.26%
# 4:   	0.48%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large
# baking:   	97.53%
# bowl:   	2.24%
# pot:   	0.16%
# nonstick:   	0.03%
# saucepan:   	0.02%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking
# sheet:   	93.06%
# dish:   	6.59%
# sheets:   	0.11%
# surface:   	0.08%
# paring:   	0.07%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet
# and:   	89.59%
# so:   	9.84%
# ;:   	0.46%
# with:   	0.07%
# ,:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and
# pick:   	45.62%
# bake:   	16.76%
# make:   	16.17%
# arrange:   	6.7%
# chill:   	5.13%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make
# a:   	99.93%
# same:   	0.03%
# sure:   	0.02%
# cold:   	0.01%
# electric:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a
# floured:   	69.8%
# large:   	16.79%
# medium:   	6.63%
# small:   	1.73%
# nonstick:   	1.48%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured
# hands:   	39.31%
# cutting:   	22.77%
# surface:   	19.16%
# sheet:   	15.1%
# depth:   	2.47%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface
# ;:   	95.51%
# .:   	2.81%
# and:   	1.14%
# ,:   	0.3%
# to:   	0.11%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ;
# season:   	91.58%
# wrap:   	3.86%
# arrange:   	2.27%
# let:   	1.28%
# brush:   	0.28%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season
# with:   	99.71%
# generously:   	0.1%
# cutlets:   	0.1%
# hens:   	0.08%
# warm:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with
# salt:   	100.0%
# remaining:   	0.0%
# foil:   	0.0%
# 2:   	0.0%
# plastic:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt
# and:   	96.13%
# .:   	3.86%
# with:   	0.0%
# ;:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and
# pepper:   	99.97%
# drizzle:   	0.02%
# top:   	0.0%
# garnish:   	0.0%
# serve:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper
# .:   	99.95%
# to:   	0.03%
# and:   	0.02%
# ;:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper .
# (:   	93.02%
# sauté:   	2.4%
# :   	1.43%
# heat:   	1.17%
# serve:   	0.62%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . (
# bread:   	97.45%
# can:   	2.06%
# cheesecake:   	0.37%
# pie:   	0.07%
# do:   	0.02%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread
# ):   	80.78%
# and:   	18.25%
# (:   	0.71%
# on:   	0.16%
# .:   	0.03%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread )
# up:   	78.75%
# .:   	20.53%
# cut:   	0.33%
# to:   	0.14%
# in:   	0.1%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) .
# toss:   	51.65%
# cut:   	17.83%
# combine:   	11.08%
# line:   	4.48%
# remove:   	2.48%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut
# butter:   	50.48%
# bread:   	46.54%
# in:   	2.16%
# a:   	0.6%
# extra:   	0.12%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread
# and:   	99.53%
# ):   	0.46%
# ;:   	0.0%
# (:   	0.0%
# on:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and
# discard:   	85.06%
# inverting:   	7.1%
# watch:   	1.79%
# invert:   	1.7%
# put:   	1.06%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting
# each:   	92.19%
# off:   	7.01%
# in:   	0.35%
# with:   	0.19%
# out:   	0.13%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off
# right:   	70.19%
# parchment:   	14.61%
# paper:   	14.47%
# more:   	0.33%
# piece:   	0.2%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right
# side:   	99.77%
# up:   	0.08%
# .:   	0.04%
# be:   	0.03%
# pockets:   	0.02%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side
# up:   	64.93%
# .:   	35.04%
# ,:   	0.02%
# before:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up
# up:   	99.93%
# .:   	0.07%
# ,:   	0.0%
# so:   	0.0%
# more:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up
# sides:   	52.43%
# up:   	46.08%
# skin:   	0.36%
# .:   	0.27%
# ,:   	0.23%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up
# sides:   	97.63%
# up:   	1.11%
# seeds:   	0.57%
# ,:   	0.3%
# to:   	0.09%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides
# ,:   	98.28%
# layer:   	1.51%
# and:   	0.06%
# juices:   	0.06%
# over:   	0.04%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides ,
# and:   	82.24%
# .:   	14.63%
# with:   	1.92%
# ,:   	0.33%
# pudding:   	0.19%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with
# a:   	56.39%
# 4:   	23.45%
# large:   	12.92%
# salt:   	1.18%
# towel:   	0.87%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4
# plates:   	99.71%
# squares:   	0.15%
# spatulas:   	0.11%
# .:   	0.01%
# filled:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates
# ,:   	42.26%
# ;:   	32.77%
# and:   	16.19%
# .:   	8.44%
# next:   	0.28%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates ,
# top:   	94.13%
# place:   	3.69%
# brush:   	0.91%
# and:   	0.77%
# each:   	0.29%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top
# with:   	98.67%
# each:   	0.92%
# and:   	0.32%
# warm:   	0.08%
# ,:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with
# chops:   	62.14%
# breadcrumbs:   	29.58%
# tagine:   	3.06%
# berry:   	2.8%
# second:   	0.36%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs
# .:   	44.13%
# of:   	34.14%
# -:   	9.07%
# and:   	6.8%
# ,:   	5.67%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs -
# bowl:   	23.07%
# and:   	15.77%
# yogurt:   	15.21%
# buns:   	12.74%
# breadcrumbs:   	8.77%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl
# and:   	83.09%
# .:   	16.88%
# with:   	0.02%
# along:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and
# serve:   	89.59%
# drizzle:   	6.37%
# sprinkle:   	1.91%
# arrange:   	1.62%
# top:   	0.3%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve
# .:   	99.97%
# with:   	0.02%
# ,:   	0.0%
# warm:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve .
# :   	89.95%
# *:   	9.65%
# (:   	0.3%
# serve:   	0.07%
# do:   	0.02%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . *
# *:   	88.77%
# pork:   	5.57%
# hot:   	5.28%
# exotic:   	0.06%
# water:   	0.06%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * *
# *:   	81.89%
# hot:   	9.79%
# pork:   	6.02%
# the:   	0.68%
# exotic:   	0.58%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * *
# *:   	55.06%
# hot:   	30.89%
# pork:   	8.93%
# the:   	1.65%
# water:   	0.96%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * *
# *:   	47.22%
# hot:   	30.24%
# pork:   	14.78%
# the:   	3.18%
# exotic:   	1.52%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * * hot
# hot:   	60.29%
# water:   	22.72%
# bread:   	4.54%
# mixture:   	3.71%
# yogurt:   	2.99%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * * hot liquids
# ahead:   	84.85%
# section:   	11.15%
# .:   	2.01%
# foods:   	0.67%
# plates:   	0.44%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * * hot liquids ahead
# .:   	99.25%
# and:   	0.59%
# ;:   	0.13%
# ::   	0.03%
# (:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; cook , onion , corn mixture in middle of oven and cook , stirring until very , stirring until very tender . add parsley and pepper . process ( can be made 1 day ahead and up up up , on large baking sheet and make a floured surface ; season with salt and pepper . ( bread ) . cut bread and inverting off right side up up up sides , with 4 plates , top with breadcrumbs - bowl and serve . * * * * hot liquids ahead .
# :   	80.1%
# (:   	4.19%
# ):   	4.11%
# bring:   	4.01%
# season:   	1.5%
# --------

# %%
# my famous third new clam chowder recipie!!!! mmm try it and taste it
info = text_generator.generate(
    "recipe for clam chowder", max_tokens=100, temperature=0.1
)
# Out:
# generated text:
# recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread and serve with olive yogurt

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for clam chowder
# ;:   	99.72%
# ,:   	0.28%
# saucepan:   	0.0%
# 2:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ;
# season:   	99.06%
# cook:   	0.57%
# toss:   	0.37%
# onion:   	0.0%
# stir:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season
# with:   	69.39%
# and:   	30.61%
# to:   	0.01%
# ,:   	0.0%
# salad:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with
# salt:   	100.0%
# pepper:   	0.0%
# 2:   	0.0%
# parsley:   	0.0%
# remaining:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt
# and:   	100.0%
# .:   	0.0%
# with:   	0.0%
# ,:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and
# pepper:   	100.0%
# salt:   	0.0%
# remaining:   	0.0%
# drizzle:   	0.0%
# bay:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper
# .:   	100.0%
# to:   	0.0%
# and:   	0.0%
# ,:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper .
# sauté:   	99.87%
# process:   	0.08%
# heat:   	0.05%
# arrange:   	0.0%
# cook:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté
# pasta:   	98.84%
# 2:   	1.08%
# 1:   	0.05%
# ,:   	0.02%
# until:   	0.01%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta
# and:   	91.58%
# in:   	7.44%
# ,:   	0.99%
# remaining:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta ,
# until:   	99.98%
# fresh:   	0.01%
# stirring:   	0.01%
# 2:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until
# very:   	99.28%
# mustard:   	0.72%
# whites:   	0.0%
# egg:   	0.0%
# browned:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very
# tender:   	100.0%
# minutes:   	0.0%
# coarse:   	0.0%
# 2:   	0.0%
# 4:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender
# .:   	99.98%
# ;:   	0.02%
# and:   	0.0%
# ,:   	0.0%
# but:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender .
# add:   	100.0%
# cook:   	0.0%
# pour:   	0.0%
# toss:   	0.0%
# stir:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add
# parsley:   	99.57%
# chili:   	0.43%
# beans:   	0.0%
# glace:   	0.0%
# mint:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley
# and:   	100.0%
# ,:   	0.0%
# ;:   	0.0%
# with:   	0.0%
# in:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and
# parsley:   	99.99%
# pepper:   	0.01%
# beans:   	0.0%
# cornstarch:   	0.0%
# bananas:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley
# and:   	100.0%
# ,:   	0.0%
# ;:   	0.0%
# over:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and
# pepper:   	100.0%
# parsley:   	0.0%
# cucumber:   	0.0%
# cornstarch:   	0.0%
# bananas:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper
# .:   	99.99%
# to:   	0.01%
# ,:   	0.0%
# ;:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper .
# process:   	100.0%
# sauté:   	0.0%
# pour:   	0.0%
# serve:   	0.0%
# thread:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process
# (:   	100.0%
# salad:   	0.0%
# .:   	0.0%
# separately:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process (
# pie:   	100.0%
# cheesecake:   	0.0%
# cup:   	0.0%
# tagine:   	0.0%
# ramekins:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie
# oil:   	100.0%
# 1:   	0.0%
# toasts:   	0.0%
# onion:   	0.0%
# separately:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil
# into:   	98.87%
# from:   	0.65%
# ,:   	0.47%
# in:   	0.0%
# /:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into
# small:   	100.0%
# a:   	0.0%
# tablespoon:   	0.0%
# prepared:   	0.0%
# cup:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small
# saucepan:   	100.0%
# bowl:   	0.0%
# spice:   	0.0%
# knife:   	0.0%
# small:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan
# .:   	100.0%
# ;:   	0.0%
# and:   	0.0%
# to:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan .
# add:   	98.89%
# finely:   	1.1%
# put:   	0.0%
# combine:   	0.0%
# pat:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add
# beans:   	73.68%
# the:   	19.33%
# clam:   	6.99%
# hot:   	0.0%
# parsley:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans
# ,:   	89.78%
# and:   	10.22%
# ;:   	0.0%
# .:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans ,
# onion:   	100.0%
# butter:   	0.0%
# and:   	0.0%
# reduce:   	0.0%
# cook:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion
# ,:   	100.0%
# and:   	0.0%
# mixture:   	0.0%
# skin:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion ,
# and:   	87.0%
# butter:   	12.71%
# rosemary:   	0.15%
# mustard:   	0.08%
# carrot:   	0.03%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter
# ,:   	100.0%
# and:   	0.0%
# in:   	0.0%
# cup:   	0.0%
# over:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter ,
# and:   	99.98%
# mustard:   	0.02%
# 1:   	0.0%
# butter:   	0.0%
# lemon:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and
# garlic:   	72.19%
# thyme:   	22.26%
# remaining:   	3.51%
# ginger:   	1.96%
# cinnamon:   	0.04%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic
# ,:   	89.28%
# and:   	10.72%
# 1:   	0.0%
# to:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and
# remaining:   	100.0%
# 1:   	0.0%
# cook:   	0.0%
# ginger:   	0.0%
# garlic:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining
# 1:   	100.0%
# olive:   	0.0%
# tablespoon:   	0.0%
# half:   	0.0%
# 2:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1
# tablespoon:   	100.0%
# /:   	0.0%
# cup:   	0.0%
# 1:   	0.0%
# tablespoons:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon
# garlic:   	99.86%
# oil:   	0.14%
# sugar:   	0.0%
# butter:   	0.0%
# cheese:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic
# and:   	95.58%
# ,:   	4.42%
# .:   	0.0%
# breasts:   	0.0%
# paste:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and
# remaining:   	100.0%
# ginger:   	0.0%
# turkey:   	0.0%
# celery:   	0.0%
# bay:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining
# 1:   	99.86%
# tablespoon:   	0.14%
# olive:   	0.0%
# 2:   	0.0%
# half:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1
# tablespoon:   	100.0%
# /:   	0.0%
# cup:   	0.0%
# teaspoon:   	0.0%
# tablespoons:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon
# garlic:   	93.19%
# oil:   	6.81%
# sugar:   	0.0%
# cheese:   	0.0%
# butter:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil
# to:   	100.0%
# in:   	0.0%
# until:   	0.0%
# /:   	0.0%
# around:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to
# medium:   	99.9%
# skillet:   	0.06%
# a:   	0.04%
# large:   	0.0%
# 350°f:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium
# bowl:   	69.82%
# saucepan:   	30.18%
# -:   	0.0%
# .:   	0.0%
# skillet:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan
# .:   	100.0%
# ;:   	0.0%
# and:   	0.0%
# (:   	0.0%
# over:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan .
# add:   	100.0%
# reduce:   	0.0%
# cook:   	0.0%
# discard:   	0.0%
# finely:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add
# parsley:   	52.91%
# brown:   	30.53%
# chili:   	8.62%
# mushrooms:   	3.6%
# water:   	2.86%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley
# and:   	100.0%
# ,:   	0.0%
# ;:   	0.0%
# in:   	0.0%
# over:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and
# parsley:   	100.0%
# pepper:   	0.0%
# cornstarch:   	0.0%
# ginger:   	0.0%
# beans:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley
# and:   	100.0%
# ,:   	0.0%
# ;:   	0.0%
# over:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and
# pepper:   	99.83%
# parsley:   	0.17%
# cornstarch:   	0.0%
# ginger:   	0.0%
# sugar:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper
# .:   	84.78%
# to:   	15.22%
# ,:   	0.0%
# ;:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper .
# process:   	100.0%
# pour:   	0.0%
# sauté:   	0.0%
# bring:   	0.0%
# pork:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process
# (:   	100.0%
# salad:   	0.0%
# .:   	0.0%
# separately:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process (
# pie:   	100.0%
# cheesecake:   	0.0%
# cup:   	0.0%
# of:   	0.0%
# ramekins:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie
# oil:   	100.0%
# toasts:   	0.0%
# 1:   	0.0%
# onion:   	0.0%
# bacon:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil
# into:   	99.6%
# ,:   	0.37%
# from:   	0.03%
# ":   	0.0%
# in:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into
# small:   	100.0%
# a:   	0.0%
# tablespoon:   	0.0%
# cup:   	0.0%
# stew:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small
# saucepan:   	100.0%
# bowl:   	0.0%
# spice:   	0.0%
# knife:   	0.0%
# small:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan
# .:   	100.0%
# and:   	0.0%
# ;:   	0.0%
# (:   	0.0%
# pan:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan .
# add:   	93.58%
# finely:   	6.41%
# combine:   	0.01%
# put:   	0.0%
# discard:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add
# clam:   	50.79%
# the:   	28.29%
# beans:   	20.87%
# hot:   	0.05%
# parsley:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans
# ,:   	58.78%
# and:   	41.22%
# ;:   	0.0%
# .:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and
# onion:   	100.0%
# parsley:   	0.0%
# simmer:   	0.0%
# cook:   	0.0%
# ginger:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion
# mixture:   	100.0%
# and:   	0.0%
# ,:   	0.0%
# .:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture
# ,:   	100.0%
# until:   	0.0%
# (:   	0.0%
# .:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture ,
# radicchio:   	99.99%
# 1:   	0.01%
# garlic:   	0.0%
# toss:   	0.0%
# remaining:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio
# ,:   	100.0%
# and:   	0.0%
# ;:   	0.0%
# 1:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio ,
# and:   	82.65%
# 1:   	17.29%
# radicchio:   	0.04%
# butter:   	0.02%
# salt:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1
# /:   	99.99%
# 1:   	0.01%
# cup:   	0.0%
# tablespoon:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 /
# 4:   	100.0%
# 2:   	0.0%
# 3:   	0.0%
# 8:   	0.0%
# large:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4
# cup:   	100.0%
# teaspoon:   	0.0%
# cupfuls:   	0.0%
# -:   	0.0%
# cups:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup
# basil:   	100.0%
# sugar:   	0.0%
# dressing:   	0.0%
# mustard:   	0.0%
# parmesan:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil
# and:   	100.0%
# ,:   	0.0%
# ;:   	0.0%
# basil:   	0.0%
# reduction:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and
# mint:   	69.53%
# parsley:   	30.4%
# salt:   	0.06%
# ginger:   	0.01%
# toss:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint
# ;:   	100.0%
# over:   	0.0%
# .:   	0.0%
# ,:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ;
# season:   	99.79%
# add:   	0.15%
# stir:   	0.06%
# toss:   	0.0%
# pour:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season
# with:   	100.0%
# salad:   	0.0%
# them:   	0.0%
# separately:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with
# salt:   	100.0%
# remaining:   	0.0%
# parsley:   	0.0%
# mint:   	0.0%
# pepper:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt
# and:   	100.0%
# .:   	0.0%
# ;:   	0.0%
# ,:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and
# pepper:   	100.0%
# serve:   	0.0%
# drizzle:   	0.0%
# top:   	0.0%
# garnish:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper
# .:   	100.0%
# and:   	0.0%
# to:   	0.0%
# ;:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper .
# (:   	94.18%
# serve:   	5.17%
# :   	0.65%
# process:   	0.01%
# do:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . (
# bread:   	99.94%
# can:   	0.06%
# cheesecake:   	0.0%
# pie:   	0.0%
# do:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread
# and:   	99.77%
# ):   	0.23%
# (:   	0.0%
# on:   	0.0%
# cheesecake:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread and
# serve:   	100.0%
# make:   	0.0%
# keep:   	0.0%
# bread:   	0.0%
# store:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread and serve
# with:   	100.0%
# warm:   	0.0%
# in:   	0.0%
# bread:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread and serve with
# olive:   	100.0%
# remaining:   	0.0%
# breadcrumbs:   	0.0%
# mint:   	0.0%
# basil:   	0.0%
# --------
#
#
# PROMPT: recipe for clam chowder ; season with salt and pepper . sauté pasta , until very tender . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans , onion , butter , and garlic and remaining 1 tablespoon garlic and remaining 1 tablespoon oil to medium saucepan . add parsley and parsley and pepper . process ( pie oil into small saucepan . add beans and onion mixture , radicchio , 1 / 4 cup basil and mint ; season with salt and pepper . ( bread and serve with olive
# yogurt:   	64.74%
# oil:   	35.26%
# olive:   	0.0%
# toasts:   	0.0%
# bacon:   	0.0%
# --------
